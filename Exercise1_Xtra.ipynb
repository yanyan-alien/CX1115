# %% [markdown]
# # Exercise 1 : Bonus and beyond ...
#
# ---
#
# ### Essential Libraries
#
# Let us begin by importing the essential Python Libraries.
#
# > NumPy : Library for Numeric Computations in Python
# > Pandas : Library for Data Acquisition and Preparation

# %%
# Basic Libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ---
#
# ## Bonus Problem : Wikipedia
#
# Import the Medal Table from https://en.wikipedia.org/wiki/2016_Summer_Olympics_medal_table as a DataFrame.

# %%
medal_html = pd.read_html('https://en.wikipedia.org/wiki/2016_Summer_Olympics_medal_table')

# %%
medalTable = medal_html[2]
medalTable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    87 non-null     object
#  1   NOC     87 non-null     object
#  2   Gold    87 non-null     int64
#  3   Silver  87 non-null     int64
#  4   Bronze  87 non-null     int64
#  5   Total   87 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 4.2+ KB

# %% [markdown]
# There are 87 rows/countries in total. Extract the top 20 rows of the `DataFrame` to capture the TOP 20 countries.

# %%
medalData = medalTable.iloc[:20]
medalData
# Out:
#    Rank                  NOC  Gold  Silver  Bronze  Total
# 0     1  United States (USA)    46      37      38    121
# 1     2  Great Britain (GBR)    27      23      17     67
# 2     3          China (CHN)    26      18      26     70
# 3     4         Russia (RUS)    19      17      20     56
# 4     5        Germany (GER)    17      10      15     42
# 5     6          Japan (JPN)    12       8      21     41
# 6     7         France (FRA)    10      18      14     42
# 7     8    South Korea (KOR)     9       3       9     21
# 8     9          Italy (ITA)     8      12       8     28
# 9    10      Australia (AUS)     8      11      10     29
# 10   11    Netherlands (NED)     8       7       4     19
# 11   12        Hungary (HUN)     8       3       4     15
# 12   13        Brazil (BRA)*     7       6       6     19
# 13   14          Spain (ESP)     7       4       6     17
# 14   15          Kenya (KEN)     6       6       1     13
# ...

# %%
hello = pd.DataFrame(medalData[["Gold", "Silver"]], index=medalData["NOC"])
# houseCatData = pd.DataFrame(houseData[['MSSubClass', 'Neighborhood', 'BldgType', 'OverallQual']])
hello
# Out:
#                      Gold  Silver
# NOC
# United States (USA)   NaN     NaN
# Great Britain (GBR)   NaN     NaN
# China (CHN)           NaN     NaN
# Russia (RUS)          NaN     NaN
# Germany (GER)         NaN     NaN
# Japan (JPN)           NaN     NaN
# France (FRA)          NaN     NaN
# South Korea (KOR)     NaN     NaN
# Italy (ITA)           NaN     NaN
# Australia (AUS)       NaN     NaN
# Netherlands (NED)     NaN     NaN
# Hungary (HUN)         NaN     NaN
# Brazil (BRA)*         NaN     NaN
# Spain (ESP)           NaN     NaN
# Kenya (KEN)           NaN     NaN
# Jamaica (JAM)         NaN     NaN
# Croatia (CRO)         NaN     NaN
# Cuba (CUB)            NaN     NaN
# New Zealand (NZL)     NaN     NaN
# Canada (CAN)          NaN     NaN

# %%
# plotData = pd.DataFrame(df2[["house_per thousand...", "blah blah"]], index=df2["location"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-dc293e66fd8e> in <module>
# ----> 1 plotData = pd.DataFrame(df2[["house_per thousand...", "blah blah"]], index=df2["location"])
#
# NameError: name 'df2' is not defined

# %% [markdown]
# **Observation** : Changing `2016` within the URL `'https://en.wikipedia.org/wiki/2016_Summer_Olympics_medal_table'` allows us to fetch any other Summer Olympic dataset similarly. Let's try to write a loop to iterate over a list of years `[2016, 2012, 2008, 2004, 2000]`, and fetch all.

# %%
first_year = 2000
last_year = 2016

for year in range(first_year, last_year + 1, 4):
    wiki_url = "https://en.wikipedia.org/wiki/" + str(year) + "_Summer_Olympics_medal_table"
    medal_html = pd.read_html(wiki_url)
    medalTable = medal_html[1]
    medalData = medalTable.iloc[:20]
    display(medalData)
# Out:
#                                                    0
# 0                                Part of a series on
# 1                               2000 Summer Olympics
# 2  Bid process (bid details) Venues Mascots Broad...
# 3  .mw-parser-output .navbar{display:inline;font-...
#                                                    0
# 0                                Part of a series on
# 1                               2004 Summer Olympics
# 2  Bid process (bid details) Venues Marketing (ma...
# 3  .mw-parser-output .navbar{display:inline;font-...
#                                                    0
# 0                                Part of a series on
# 1                               2008 Summer Olympics
# 2  Bid process (bid details) Venues Marketing (ma...
# 3  .mw-parser-output .navbar{display:inline;font-...
#                                                    0
# 0                                Part of a series on
# 1                               2012 Summer Olympics
# ...

# %% [markdown]
# Can this be done for any year? What about `1980`?

# %%
year = 1980    
wiki_url = "https://en.wikipedia.org/wiki/" + str(year) + "_Summer_Olympics_medal_table"
medal_html = pd.read_html(wiki_url)
medalTable = medal_html[0]
medalData = medalTable.iloc[:20]
display(medalData)

# %% [markdown]
# Yes, it is possible. But the medal table is now at index `0` of the html table list, and not at index `1`.

# %% [markdown]
# ### Generic Loop to Scrape
#
# It turns out that Wikipedia has medal table at index `0` for years from `1896` to `1988`, and at index `1` for years from `1992` to `2016`. So, we will need to indicate the table matching "*Rank*" to scrape the correct table all the time. Also note that Summer Olympics were not held in `1916`, `1940`, `1944`, due to the world wars. So, we will omit those years manually. Let's get only TOP 10 this time, for every year Summer Olympics took place.

# %%
first_year = 1896
last_year = 2016
omit_years = [1916, 1940, 1944]

for year in range(first_year, last_year + 1, 4):
    # skip the years olympics did not take place
    if year in omit_years:
        continue

    # fetch the html page with the url for year
    wiki_url = "https://en.wikipedia.org/wiki/" + str(year) + "_Summer_Olympics_medal_table"
    
    # scrape table(s) only if it matches "Rank"
    medal_html = pd.read_html(wiki_url, match = "Rank")
    medalTable = medal_html[0]
    
    # extract only TOP 10 countries in the table
    medalData = medalTable.iloc[:10]
    
    # display the year and the top 10 countries
    print()
    print("================================================")
    print(year)
    display(medalData)
# Out:
# ...
# 1896
#   Rank               Nation  Gold  Silver  Bronze  Total
# 0    1  United States (USA)    11       7       2     20
# 1    2        Greece (GRE)*    10      18      19     47
# 2    3        Germany (GER)     6       5       2     13
# 3    4         France (FRA)     5       4       2     11
# 4    5  Great Britain (GBR)     2       3       2      7
# 5    6        Hungary (HUN)     2       1       3      6
# 6    7        Austria (AUT)     2       1       2      5
# 7    8      Australia (AUS)     2       0       0      2
# 8    9        Denmark (DEN)     1       2       3      6
# 9   10    Switzerland (SUI)     1       2       0      3
# ...
# 1900
#   Rank                  Nation  Gold  Silver  Bronze  Total
# 0    1         France (FRA)[a]    27      38      37    102
# 1    2  United States (USA)[a]    19      14      15     48
# 2    3  Great Britain (GBR)[a]    15       8       9     32
# 3    4        Mixed team (ZZX)     8       5       6     19
# ...

# %% [markdown]
# If you understood the logic so far, it's only a matter of time till you can do the following with the tables.

# %%
first_year = 1896
last_year = 2016
omit_years = [1916, 1940, 1944]

medalDataFrames = []

for year in range(first_year, last_year + 1, 4):
    # skip the years olympics did not take place
    if year in omit_years:
        continue

    # fetch the html page with the url for year
    wiki_url = "https://en.wikipedia.org/wiki/" + str(year) + "_Summer_Olympics_medal_table"
    
    # scrape table(s) only if it matches "Rank"
    medal_html = pd.read_html(wiki_url, match = "Rank")
    medalTable = medal_html[0]
    
    # extract only TOP 10 countries in the table
    medalData = medalTable.iloc[:10]
    
    # rename the columns to make tables uniform
    medalData.columns = ["Rank", "Nation", "Gold", "Silver", "Bronze", "Total"]
    
    # store the medal dataframe in the main list
    medalDataFrames.append(medalData)
    
medalDataAll = pd.concat(medalDataFrames, axis = 1)

# %% [markdown]
# Now that you've got all the data for TOP 10 teams from `1896` to `2016`, go ahead and do whatever you want!

# %%
# e.g., Nations across the years in TOP 10 list
medalDataAll.Nation

# %% [markdown]
# ---
#
# ## Extra Problem : Just for fun!
#
# Any structured website can be scraped for tables in the same way. However, what would you do for data that are not in a table format? Can you extract the name of the movie, its rating and genres from https://www.imdb.com/title/tt0441773/ using some other library in python? Give it a shot! :-)

# %%
# first, you will need a GET REQUEST for the HTML
from requests import get
url = 'https://www.imdb.com/title/tt0441773/'
response = get(url)

# then, you will need Beautiful Soup for the data
from bs4 import BeautifulSoup
html_soup = BeautifulSoup(response.text, 'html.parser')

# %%
# once you got the html_soup, extract the title_block
title_block = html_soup.find_all('div', class_ = 'title_block')[0]
title_block

# %%
# now you can extract targeted data from this mess
print("Rating : ", title_block.div.strong.span.text)
print("Title  : ", title_block.h1.text)
print("Year   : ", title_block.h1.span.a.text)

# %%
# extracting multiple occurrences is a little tricky
genres = title_block.find('div', class_ = 'subtext')
for x in genres.find_all('a')[:3]:
    print(x.text)

# %% [markdown]
# **Most interesting :** Can you try and download the poster for the movie? That would be real fun! Then, loop through multiple movies. :-)
